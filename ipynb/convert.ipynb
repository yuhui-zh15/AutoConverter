# %%
import json

samples = json.load(open("samples/samples.json"))

# for idx, item in enumerate(samples):
#     image = base64_to_image(item["image"])
#     image.save(f"samples/{idx}.png")

# %%
from pydantic import BaseModel
from openai import OpenAI
from textwrap import dedent
from PIL import Image
import base64
import io


client = OpenAI()

class Distractor(BaseModel):
    text: str
    reason: str

class Distractors(BaseModel):
    distractors: list[Distractor]


def base64_to_image(base64_str):
    """
    Convert a base64 string to a PIL Image.
    
    Args:
        base64_str (str): The base64 encoded image string.
        
    Returns:
        PIL.Image.Image: The image object.
    """
    # Decode the base64 string into bytes
    image_data = base64.b64decode(base64_str)
    
    # Convert bytes into a PIL image
    image = Image.open(io.BytesIO(image_data))
    
    return image


# def convert_to_multi_choice(item):
#     question = item["question"]
#     answer = item["answer"]
#     image_base64 = item["image"]

#     system_prompt = "You are a helpful assistant."
#     user_prompt = f"""Please generate 3 distractors for this question given the image:

#     Question: {question}
#     Answer: {answer}
#     """

#     completion = client.beta.chat.completions.parse(
#         model="gpt-4o",
#         messages=[
#             {"role": "system", "content": dedent(system_prompt)},
#             {
#                 "role": "user",
#                 "content": [
#                     {"type": "text", "text": dedent(user_prompt)},
#                     {
#                         "type": "image_url",
#                         "image_url": {"url": f"data:image/png;base64,{image_base64}"},
#                     },
#                 ],
#             },
#         ],
#         response_format=Distractors,
#     )

#     distractors = completion.choices[0].message.parsed.dict()
#     choices = [answer] + [distractor["text"] for distractor in distractors["distractors"]]
#     reasons = [None] + [distractor["reason"] for distractor in distractors["distractors"]]
#     multi_choice_questions = {
#         "question": question,
#         "choices": choices,
#         "reasons": reasons,
#         "answer": answer,
#     }
#     return multi_choice_questions


def get_reply(system_prompt, user_prompt, image_base64, output_format):
    completion = client.beta.chat.completions.parse(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": dedent(system_prompt)},
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": dedent(user_prompt)},
                    {
                        "type": "image_url",
                        "image_url": {"url": f"data:image/png;base64,{image_base64}"},
                    },
                ],
            },
        ],
        response_format=output_format,
    )
    parsed_output = completion.choices[0].message.parsed.dict()
    return parsed_output




from prompts import concept_generation_system_prompt, reasoning_generation_system_prompt, visual_interpretation_generation_system_prompt, data_processing_generation_system_prompt, question_bias_generation_system_prompt, fusion_generation_system_prompt
def convert_to_multi_choice(item):
    question = item["question"]
    answer = item["answer"]
    image_base64 = item["image"]

    user_prompt = f"""
    Question: {question}
    Answer: {answer}
    """

    distractors_concept = get_reply(concept_generation_system_prompt, user_prompt, image_base64, Distractors)["distractors"]
    distractors_reasoning = get_reply(reasoning_generation_system_prompt, user_prompt, image_base64, Distractors)["distractors"]
    distractors_visual_interpretation = get_reply(visual_interpretation_generation_system_prompt, user_prompt, image_base64, Distractors)["distractors"]
    distractors_data_processing = get_reply(data_processing_generation_system_prompt, user_prompt, image_base64, Distractors)["distractors"]
    distractors_question_bias = get_reply(question_bias_generation_system_prompt, user_prompt, image_base64, Distractors)["distractors"]

    # user_prompt = f"""
    # Question: {question}
    # Answer: {answer}

    # Given the distractors generated already:
    # ```{distractors_concept}```
    
    # Please think carefully about how to improve these distractors and refine these distractors.
    # """
    # distractors_concept = get_reply(concept_generation_system_prompt, user_prompt, image_base64, Distractors)["distractors"]
    # print(distractors_concept)
    

    distractors = distractors_concept + distractors_reasoning + distractors_visual_interpretation + distractors_data_processing + distractors_question_bias
    


    # user_prompt = f"""
    # Question: {question}
    # Answer: {answer}
    # All Distractors: {distractors}
    # """

    # distractors = get_reply(fusion_generation_system_prompt, user_prompt, image_base64, Distractors)["distractors"]

    choices = [answer] + [distractor["text"] for distractor in distractors]
    reasons = [None] + [distractor["reason"] for distractor in distractors]
    multi_choice_questions = {
        "question": question,
        "choices": choices,
        "reasons": reasons,
        "answer": answer,
    }
    return multi_choice_questions

# %%
mcqs = [] 
for item in samples:
    mcq = convert_to_multi_choice(item)
    mcqs.append(mcq)

    # display(dataset_4choices[0])
    # display(mcq)

json.dump(mcqs, open("samples/mcqs_agent_all.json", "w"), indent=2)

# %%
import json
data = json.load(open("samples/mcqs_agent_all.json"))
samples = json.load(open("samples/samples.json"))
assert len(data) == len(samples)

for idx in range(len(data)):
    display(base64_to_image(samples[idx]["image"]).resize((384, 384)))
    
    print("Question:", data[idx]["question"])
    print("Answer:", data[idx]["answer"])
    for i in range(1, 31, 6):
        print(["concept", "reasoning", "visual_interpretation", "data_processing", "question_bias"][i // 6])
        # distractors_concept + distractors_reasoning + distractors_visual_interpretation + distractors_data_processing + distractors_question_bias
        print("Choices:", data[idx]["choices"][i:i+6])
        print("Reasons:", data[idx]["reasons"][i:i+6])
    # print("Reasons:", data[idx]["reasons"])
    print("\n\n")
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: What will the girl on the right write on the board?
# Answer: 14
# concept
# Choices: ['9', '7', '12', '5', '11', '8']
# Reasons: ['This distractor confuses the multiplication equation solved by the first child (3 x 3) with the subtraction problem meant for the girl on the right.', 'This option mistakenly considers the operation as subtraction of the digits, incorrectly simplifying the subtraction from 11 - 2 to a visually similar but conceptually flawed calculation.', 'This distractor miscalculates the result of subtracting two from 11, possibly due to misreading the numbers or mistakenly applying an incorrect rule of subtraction.', 'This option assumes an incorrect operation, such as a combination of the digits or a misinterpretation of the symbols involved in the subtraction 11 - 2.', 'This response indicates an erroneous belief that subtraction results in the original minuend number, neglecting the actual effect of the operation.', 'This distractor incorrectly applies partial subtraction and omits understanding of the entire numerical value to be deducted, resulting in a common simple arithmetic error.']
# reasoning
# Choices: ['13', '10', '9', '8', '5', '3']
# Reasons: ['The option might be chosen due to a miscalculation of the subtraction problem or confusion with similar numbers.', 'This reflects a neglect of crucial contextual information in performing the subtraction correctly.', 'This arises from falsely assuming the operation is an addition or misunderstanding the subtraction process.', "This option results from ignoring the difference between a single digit subtraction strategy and miscalculating '11-2'.", 'It involves inappropriate simplification of the subtraction, perhaps treating it as a division or significantly reducing the number before subtracting.', 'It shows a misplaced focus on the visual goal, confusing mathematical operation with a random choice of small numbers.']
# visual_interpretation
# Choices: ['12', '9', '22', '5', '3', '8']
# Reasons: ['This distractor arises from misreading the subtraction as adding instead, therefore reaching a result of 12 from 11+1.', 'Selecting this option could stem from confusing the subtraction sign as a division, leading one to erroneously calculate it as 11 divided by 2 without considering integer rounding.', 'This option may seem plausible by adding 11+11, misunderstanding the equation format on the board and incorrectly doubling the initial number.', 'This might be a confusion where subtraction is performed with reversing the order, incorrectly interpreting the task as 2 minus 11.', 'Generating this distractor involves interpreting the question as the result of 11 divided by 3, an operation unrelated to the numbers but mistakenly attributed to visual pattern recognition.', 'Misreading the problem, this distractor could result from subtracting the numbers twice, or inadvertently solving the nearby problem instead of the current one.']
# data_processing
# Choices: ['9', '5', '13', '8', '22', '19']
# Reasons: ['This distractor results from solving the first equation (3x3) instead of the third one, indicating a mistake in problem selection.', 'This could arise from miscalculating subtraction as 11-(2+4), adding instead of subtracting correctly.', 'This option could result from mistakenly subtracting 1 instead of 2, which is a common simple arithmetic error.', 'Confusing different operations or numbers could lead someone to incorrectly perform 11-3 instead of 11-2.', 'This stems from a misinterpretation of the operation needed, as if performing 11 multiplied by 2, rather than subtraction.', 'This error could occur due to mistakenly adding 11+2 instead of subtracting, leveraging a basic addition error.']
# question_bias
# Choices: ['9', '21', '23', '22', '16', '12']
# Reasons: ['This is the solution to the multiplication 3x3 that is visible in the image, making it a plausible but incorrect choice.', 'A potential solution if someone misreads the operation on the board as 7+14 instead of 7x2, exploiting a visual confusion.', 'This number could result from a mistaken operation, such as adding the numbers sequentially, 11+2, instead of performing 11-2.', 'This could arise from mistakenly doubling 11 instead of subtracting, confusing multiplicative and additive reasoning.', 'This is incorrect but plausible as it may result from incorrect mental arithmetic, adding 11+5 instead of subtracting 2.', 'An erroneously chosen result if the person incorrectly computes the solution by mistakenly writing down a common answer to a similar lookalike problem.']
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: What is the price for tomatoes?
# Answer: 8.0
# concept
# Choices: ['7.0', '9.0', '5.0', '12.0', '15.0', '10.0']
# Reasons: ["This option might mislead as '7.0' is a common price tag on the image, but it applies to different items.", "This distractor could be chosen because a price tag '9.0' is visible, potentially confusing with other red items.", "This distractor is an attractive option because '5.0' is visible in the clutter, but it applies to a different product.", 'Students might choose this based on a misreading of the area where tomatoes are located, mistaking signs on nearby fruits.', "The price '15.0' is prominent on other fruits, possibly misleading students when scanning for similar values.", 'This is generated to indicate a common numerical choice not directly unsupported by the image, encouraging an error in estimation.']
# reasoning
# Choices: ['7.0', '9.0', '10.0', '12.0', '5.0', '15.0']
# Reasons: ["This distractor is plausible because it matches the value for some other items in the image, making it a seemingly valid choice due to proximity, but it's incorrect for tomatoes.", 'This option might seem correct as it is a common price in the image, and tomatoes are near it, causing confusion through association.', 'This price is plausible by following a faulty analogy with prices that are relatively higher, assuming bigger numbers are for standard items like tomatoes.', 'This incorrect option results from ignoring the clear pricing sign next to the tomatoes, mistaking it for a similar-looking item near the bottom of the image.', 'This answer exploits the reasoning error of misattributing price to the wrong cluster of numbers visible near the tomatoes, though it refers to a different fruit.', 'The distractor plays on the fallacy of assuming higher prices correlate to quality produce like tomatoes without validating the label assigned to them.']
# visual_interpretation
# Choices: ['7.0', '9.0', '10.0', '5.0', '12.0', '15.0']
# Reasons: ['This distractor is plausible because it matches several visible prices in the image, such as those on apples and lemons, which may cause confusion if the viewer overlooks the specific signage for tomatoes.', 'This option is misleading because it corresponds to the price label next to the tomato sign, so at first glance, it may appear to be associated with the tomatoes.', "Although not visibly corresponding to any price, it's a common numeric error people make if they're quickly scanning the image without focusing on specific tags.", 'This distractor is likely to confuse as it is prominently placed on a nearby sign, leading to potential misreading if the viewer does not focus closely on the tomato section.', 'This price, although clearly marked for oranges, can be confused with the tomatoes if the viewer is overwhelmed by the visual complexity and does not carefully read the signs.', 'This is the highest visible price, which may attract attention and mislead viewers if they assume larger numbers might hint at broader price ranges.']
# data_processing
# Choices: ['7.0', '9.0', '5.0', '12.0', '15.0', '100']
# Reasons: ['This distractor may arise from incorrectly associating the 7.0 price tag attached to nearby produce items, leading to a confusion.', 'The distractor presents an error in selecting the wrong label located close to the tomatoes, which can happen if the labels are misread or misaligned in viewing.', 'This distractor comes from mistaking the price tag intended for another item further away, possibly due to overlooking the correct positioning of the tags.', 'This option might be mistakenly chosen by interpreting another visible sign nearby as applicable to the tomatoes, reflecting a misplacement of spatial perception.', 'Errors such as swapping digits or mistaking signs can lead to choosing this value, influenced by visually complex environments.', 'This reflects a severe unit or magnitude misinterpretation, where the use of a round number might seem logical but is misplaced in the context of the produce prices.']
# question_bias
# Choices: ['7.0', '9.0', '10.0', '5.0', '12.0', '15.0']
# Reasons: ['This option is plausible because it appears multiple times for various fruits and vegetables, making it an easily confused alternative.', 'This distractor is located very near the appropriate area of focus, leading to potential mis-association especially since it is written similarly to the correct answer.', "This option exploits the viewer's potential misreading of nearby displayed prices as many items in the image have closely priced tags.", 'Placing this option targets those who may confuse the signs or overlook the association between produce and price, as it can be seen in a prominent location.', 'This choice capitalizes on potential misalignment when reading the sign while assuming an ascending order of prices, especially given it appears higher than others.', "It challenges one's attention to detail by placing a higher price near similar produce, testing assumptions about typical pricing patterns."]
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: <image 1> The structural formula of the glycinium cation is shown above. Arrows indicate the $pK_a$ values for the labile protons in the molecule. Which of the following is true about the geometry of the glycinium cation?
# Answer: Both C atoms and both O atoms lie in the same plane.
# concept
# Choices: ['The nitrogen atom lies in the same plane as all carbon atoms.', 'All hydrogen atoms are aligned along a single axis.', "The carbonyl group's oxygen atoms are tetrahedrally arranged.", 'Only the central carbon atom is in the same plane as both oxygen atoms.', 'Both nitrogen and the carboxylate group lie perpendicular to each other.', 'The molecule is completely non-planar due to steric hindrance.']
# Reasons: ['Students might mistakenly assume planar geometry similar to aromatic systems, misunderstanding the sp3 hybridization of the nitrogen atom in this molecule.', 'This option targets confusion about the 3D arrangement of hydrogen atoms, as students may incorrectly believe in collinear geometry due to simplified structural diagrams.', 'Students might incorrectly apply knowledge about tetrahedral geometry, often associated with single-bonded atoms, to a double-bonded carbonyl group.', 'This option exploits possible confusion about which carbon atom, if any, is planar with the oxygen atoms, ignoring conjugation effects that dictate planarity.', 'This distractor suggests incorrect stereochemical orientation, tempting students to forget about planarity enforced by conjugation and resonance.', 'Students might incorrectly assume non-planarity due to spatial crowding, misunderstanding the influence of resonance stabilization and hybridization on molecular geometry.']
# reasoning
# Choices: ['The N atom is out of the plane formed by the carbon skeleton.', 'The hydrogen atoms attached to the nitrogen are in the same plane as the carbonyl carbon.', 'Only one of the oxygen atoms lies in the same plane as the carbon skeleton.', 'The carbon-nitrogen bond is longer than the carbon-carbon bond due to resonance.', 'Labile protons create non-planarity in the molecule.', 'The structure is entirely linear from nitrogen to the terminal oxygen atom.']
# Reasons: ['This option seems plausible because the nitrogen can have a pyramidal shape, but the flaw is that resonance and hybridization can keep it in the plane with adjacent atoms.', 'This option incorrectly assumes that the nitrogen bonds are planar like the carbonyl group, neglecting potential tetrahedral geometry around nitrogen.', 'This distractor suggests asymmetry in the geometry that is unlikely in such molecules, ignoring the electron delocalization that promotes planarity.', 'Resonance usually shortens bonds, making them similar in length, but this option erroneously flips this reasoning.', "This option misinterprets the pKa data to infer incorrect geometry changes, ignoring that planarity isn't disrupted by the presence of ionizable protons.", 'The option falsely implies linear alignment, misunderstood from the ability of sp2 hybridization to create planer but not linear geometry.']
# visual_interpretation
# Choices: ['The N atom is out of plane with the C and O atoms.', 'Both C atoms and the N atom form a linear chain.', 'Only one of the O atoms lies in the plane with the C atoms.', 'Hydrogen atoms determine the planarity of the molecule.', 'The molecule exhibits a tetrahedral geometry around each C atom.', 'The glycinium cation is non-planar due to steric hindrance.']
# Reasons: ['This distractor exploits the common misunderstanding that nitrogen atoms can easily misalign with carbon or oxygen due to hybridization or lone pair repulsion.', 'This option misinterprets the typical bond angles and hybridization of carbon and nitrogen, leading to an incorrect assumption of linearity.', 'Misinterpretation can arise from overlooking the electron delocalization and resonance that typically align oxygen atoms with other atoms in a planarity.', 'This distractor stems from the erroneous belief that hydrogen atoms, which are usually peripheral, influence the molecular planarity.', 'This is a common mistake that arises from equating tetrahedral geometry with all carbons without considering resonance and double bonds.', 'Misinterpretation of possible steric interactions due to misjudging the size and positioning of hydrogen atoms can lead to this distractor.']
# data_processing
# Choices: ['Only the O atoms lie in the same plane.', 'Both N and C atoms lie in the same plane.', 'The molecule has a tetrahedral geometry overall.', 'The N atom and both C atoms lie in the same plane.', 'Only one O atom is in the plane of the C atoms.', 'All atoms in the molecule are planar.']
# Reasons: ['This distractor confuses the planarity of the molecule, suggesting selective planarization that may not be viable chemically.', 'This distractor assumes incorrect hybridization or molecular geometry, focusing incorrectly on nitrogen being in the same plane as carbon without considering the correct molecular shape.', 'This distractor suggests a misunderstanding of the hybridization of the carbon atoms in the molecule, leading to an incorrect assumption of tetrahedral geometry.', 'This option incorrectly assumes that all sp3 hybridized atoms can be planar, which does not apply to the nitrogen and the central carbon in this molecular structure.', 'This distractor arises from a misinterpretation of the molecular structure, overlooking the conjugation and resonance that likely planarize the moiety.', 'This option incorrectly assumes a complete planar geometry without considering the hybridization states and actual spatial structure of all the atoms within the molecule.']
# question_bias
# Choices: ['The nitrogen atom is out of the plane defined by the C and O atoms.', 'All hydrogen atoms are in the same plane as the carbon atoms.', 'The double-bonded oxygen atom is pyramidal.', 'All atoms are in a single plane.', 'Both oxygen atoms are sp3 hybridized, resulting in non-planar geometry.', 'The nitrogen-hydrogen bonds lie in the same plane as the carboxyl group.']
# Reasons: ['Nitrogen atoms in amines typically have a trigonal pyramidal geometry due to lone pair repulsion. However, resonance in the glycinium cation planarizes the nitrogen, misleadingly suggesting out-of-plane geometry.', 'The tetrahedral geometry around sp3 hybridized carbon typically places one hydrogen out of the plane, making the statement superficially plausible yet incorrect in resonance-stabilized structures like glycinium.', 'Oxygen in carbonyls generally exhibits sp2 hybridization and is planar, creating confusion by invoking a pyramidal geometry typically seen in sp3 hybridized lone pairs.', 'While partial resonance can promote coplanarity, the presence of tetrahedral centers prevents complete planarity, challenging understanding of 3D molecular structures.', 'Lone pair repulsion might suggest 3D geometry, but in resonance-stabilized species, sp2 hybridization predominates, inducing planarity.', 'The incorrect assumption comes from confusing amine and carboxyl group planarity; resonance only affects the peptide linkage, not individual NH bonds.']
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: what does the plate say?
# Answer: lff 880
# concept
# Choices: ['iff 880', 'lff 8800', 'lrf 880', 'uff 880', 'lff 805', 'lpf 880']
# Reasons: ["This option is plausible because the 'L' and 'I' can visually appear similar, especially if the viewer is not paying close attention.", 'This distractor might seem correct due to an extra digit, which can be mistakenly perceived as a stylistic or design factor of the plate.', "Confusing 'L' with 'R' is a common visual misinterpretation due to their similar shapes, leading to this plausible mistake.", "This option plays on the possible misreading of characters due to the typeface or lighting, where 'L' is misread as 'U'.", 'The numbers might be misread due to the angle of the photograph or a quick glance, making this an easy error to make.', "Swapping letters is a common error, especially under casual observation where 'F' and 'P' may seem interchangeable."]
# reasoning
# Choices: ['LFF 8800', 'IFF 880', 'EFF 880', 'LFF 888', 'U 42 USA', 'LFP 880']
# Reasons: ['This option includes an extra zero, exploiting the tendency to overlook details, which creates a hasty generalization error.', "The change from 'L' to 'I' plays on the similarity between these letters, leading to a possible perception error and context neglect.", "By substituting 'L' with 'E', this option creates a false analogy by assuming similar forms have the same information.", 'This option assumes symmetry in numbers and letters to appear correct, leading to a complex reasoning flaw where pattern recognition overrides accurate reading.', 'This attempts a cross-comparison between elements on the plate, assuming the most visible text is the focal point, causing a context neglect error.', "Replacing 'F' with 'P' is a typographical distraction, tempting the reader to accept visually similar letters without verification, which leads to a casual inversion of interpretation."]
# visual_interpretation
# Choices: ['uff 880', 'lfe 880', 'lff 830', 'lft 880', 'iff 880', 'lff 886']
# Reasons: ["The distractor could be chosen due to a visual misreading of the first character 'L' as a 'U', especially if the viewer is not observing carefully.", "This option is plausible as the letter 'E' might be visually confused with 'F' due to their similar shapes and close positioning.", "This misinterpretation might occur if the viewer mistakes the '8' for a '3' due to similar top halves.", "The distractor could be chosen by the viewer confusing the second 'F' with a 'T', which can happen if the tail of the 'F' is not noted properly.", "A viewer might mistake the 'L' for an 'I', especially if they perceive it as a capital kind, which can look similar in certain fonts.", "The final digit '0' might be misread as a '6', especially if the viewer is not observing the clean closed loop of the '0'."]
# data_processing
# Choices: ['IFF 890', 'LFF 808', 'IFF 888', 'LFF 800', 'LFF 8800', 'LLF 880']
# Reasons: ["This option is generated by confusing the letter 'L' with 'I' and changing the number '8' to '9,' a common error in text recognition.", 'This distractor swaps the last two digits, commonly occurring due to careless reading or typographical errors.', "By changing all '8's to '9's, the number becomes similar and understandably confusing, especially if relying on pattern recognition rather than exact reading.", "This option is created by rounding down the last two digits to '00,' a possible error in transcription, confusing zeros with eights or due to estimation habits.", 'Extra digits are added at the end, reflecting a type of error where digits go unnoticed due to quick reading, ignoring the typical format of license plate numbering.', "A simple swap of the second and first letter 'L' creates a common error where similar characters are misordered due to rapid visual processing."]
# question_bias
# Choices: ['lft 880', 'iff 880', 'lff 808', 'lfp 880', 'eff 880', 'lff 881']
# Reasons: ["The letter 'T' could be mistaken due to similar shape when viewed on worn or older plates.", "The letter 'I' might be confused with 'L' in certain fonts or due to shadowing.", 'The numbers could be misread if the alignment or angle causes digits to appear differently.', "The letter 'P' might seem plausible if there's dirt or damage partially obscuring the bottom loop of the 'F'.", "The letter 'E' might be assumed if the first letter appears somewhat closed or distorted.", "The '1' could be mistaken if visual cues such as light reflection create a line effect."]
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: what is the name of this course?
# Answer: the general
# concept
# Choices: ['the admiral', 'the captain', 'par 14', 'the marshal', 'the commander', 'hole 14']
# Reasons: ["This option challenges the understanding by suggesting a military-related name similar to 'The General', creating confusion due to similar themes.", "'The Captain' appears plausible as it continues the theme of leadership and rank but is incorrect, leading students to mistake the correct name for another rank.", "This option incorrectly interprets '14' as part of the course name rather than the hole number, exploiting a visual mistake in reading the sign.", "By proposing 'The Marshal', this option plays on the similar theme of military titles, misguiding students through thematic parallels.", "Suggesting 'The Commander' misleads by offering another military-related title, confusing the course's name with similar hierarchical terms.", "This response mistakes the specific hole number for the course's name, focusing on numerical identification rather than the actual title."]
# reasoning
# Choices: ['par 4', '357', 'hole 14', '341', 'map illustration', 'the flag']
# Reasons: ["This option focuses on a detail about the course but fails to recognize that 'Par 4' refers to a hole's difficulty level, not the course name.", "This distractor mistakenly interprets numerical data as the course's name, when in fact, numbers typically indicate distances or measurements on a golf course.", "By citing 'Hole 14,' this option confuses the specific hole identifier with the overall name of the course, ignoring the sign's clear label.", "This option takes numeric hole yardage information and inaccurately represents it as the course's name, mistaking supplementary information for a label.", "Mistaking the map's visual for the course name, this option incorrectly assumes that the course's layout representation is its identifier.", 'This option derives its name from a flag symbol, misinterpreting symbolic imagery as the name rather than recognizing it as a motif or logo.']
# visual_interpretation
# Choices: ['par 4', 'hole 14', 'the greens', 'the fairway', 'the bunker', 'tee off spot']
# Reasons: ["This distractor is plausible because 'Par 4' is prominently displayed and can be misunderstood as the name due to its larger font size.", "This option can be misleading because the large '14' can be interpreted as a significant name or title if someone overlooks the surrounding context.", "This distractor might confuse viewers since 'the Greens' evokes imagery related to golf courses and might be mistaken for the course's name.", 'This choice is plausible due to the golf-related term, potentially leading to confusion with the name of the course.', "This option capitalizes on golf terminology visible in the layout, which might mislead someone into thinking it's referencing the course name.", 'This is plausible if viewers focus on the golfing aspects hinted at in the visual without observing the actual course name.']
# data_processing
# Choices: ['majestic greens', 'four seasons', 'par excellence', "eagle's landing", 'flagstone ridge', 'skyline trace']
# Reasons: ["The word 'majestic' can also imply grandeur, akin to 'general', but it misreads the actual name on the signage.", "This distractor mistakenly interprets numerical data (e.g., '14' for hole number) as referring to seasons instead of recognizing the actual course name.", "This option misleadingly uses 'par' from the sign, connecting it to a golf term, but it's not the course name.", "This misinterprets the visual icon on the sign as an eagle but completely bypasses the literal text stating 'the general'.", 'A mix-up of the flag icon and possible geological reference results in this plausible but incorrect name.', "This distractor creatively misinterprets the landscape references visible in the signage but misses the textual clue of 'the general.'"]
# question_bias
# Choices: ['The Commander', 'The Captain', 'The Major', 'The Admiral', 'The Colonel', 'The Lieutenant']
# Reasons: ["'The Commander' can be misleading due to its connotations with leadership and military, similar to 'The General.' This option might be incorrectly chosen because it evokes a similar authoritative theme.", "The title 'The Captain' is plausible given its hierarchy below 'General,' creating a false sense of relativity in course naming conventions. It challenges the understanding of naming patterns while being incorrect.", "'The Major' is deceptive as it represents another military rank, likely to mislead those associating the course with military themes. This distractor capitalizes on potential confusion with related nomenclature.", "'The Admiral' is a high-ranking naval officer title that might tempt those seeking a military-related name. This option's subtle error lies in naval rather than army association, making it incorrect.", "'The Colonel' provides a similar hierarchical feel to 'The General,' offering a false familiarity as a plausible alternative. It seeks to mislead through close military rank associations.", "'The Lieutenant' is misleading due to its proximity in rank structure, offering a credible but incorrect choice. The subtle flaw lies in its lower rank, diverging from the intended 'general' theme."]
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: What is the number above the line?
# Answer: 212
# concept
# Choices: ['221', '312', '213', '210', '202', '512']
# Reasons: ['This distractor is plausible due to a reversal of numbers, which is a common visual confusion error.', 'This option suggests a misreading where the reader assumes a mix-up in number order, leading to an incorrect interpretation.', 'This choice involves a simple transposition error, which is a common mistake when reading numbers in sequence.', 'This option combines a visual and numerical similarity, misinterpreting the second digit while maintaining some similarity to the correct answer.', 'This distractor is plausible by repeating the first digit, leading to a potential flaw in recalling the correct sequence.', 'It introduces a larger numerical change by swapping the first digit, which could confuse those who recall the numbers loosely.']
# reasoning
# Choices: ['573', '4503', '490', 'W705', '673', '49']
# Reasons: ['This option draws focus to the most visually prominent number below the line, leading to a context neglect error by ignoring the number above.', "By selecting this number, it demonstrates a misunderstanding of the question's orientation, confusing the position of numbers relative to the line.", 'Suggests misinterpreting secondary information, inadvertently promoting hasty generalization from surrounding numbers without considering the positioning.', 'Introduces an irrelevant element from the image, causing potential confusion through false analogy by assuming all numbers hold similar significance.', 'Promotes incorrect parallel reasoning by relating it to the other numbers on the page without acknowledging its separate context.', 'This hasty generalization overlooks the full structure of numbers, distilling it to the smallest visible, incomplete part.']
# visual_interpretation
# Choices: ['312', '112', '210', '211', '272', '252']
# Reasons: ["This option might arise from misreading the '2' due to its size or shape, seeing it as a '3'.", "Misinterpreting the vertical alignment of the number could lead someone to drop the first digit, interpreting it as '112'.", "Visual similarity in handwriting might cause someone to incorrectly identify the numbers '2' and '1' as a zero.", "This is a classic misreading of the final digit, mistaking the '2' for a '1' due to its form or size.", "A slight curve in the handwriting might confuse a viewer into seeing '1' as '7'.", "The straight lines in the '1' might be confused with a '5' due to the script's handwritten nature."]
# data_processing
# Choices: ['221', '213', '122', '312', '112', '202']
# Reasons: ["This distractor is generated by transposing the digits '1' and '2', a common mistake in reading numbers.", 'This option results from a subtle numerical error where the last digit is increased by one, which can occur during quick writing or reading.', 'This distractor flips the first two digits to create a plausible but incorrect option due to misinterpretation.', "This distractor swaps the placement of '2' and '3', a common error when numbers are not focused on closely.", 'This distractor involves decrementing the second digit, which can happen when misreading closely packed digits.', 'This option replaces the middle digit with a zero, which can occur when reading numbers with a faulty or casual glance.']
# question_bias
# Choices: ['213', '215', '312', '112', '202', '221']
# Reasons: ['This distractor adds one to the correct number, which may seem plausible if one misreads the number slightly.', "A common mistake might involve seeing the '2' as a '5', confusing 212 with 215.", 'This option replaces the first digit, challenging the assumption of a three-digit pattern but incorrectly.', "It's plausible if one reads the first digit incorrectly, interpreting as a '1' instead of '2'.", 'This distractor tests attention to detail by replacing the middle digit, making it a reasonable incorrect choice.', 'This option switches the last two digits, creating a believable but incorrect permutation of the correct number.']
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: What is the 'total respondents' in the Test cell?
# Answer: 276
# concept
# Choices: ['299', '167', '241', '94', '38', '61']
# Reasons: ['This mistake may arise from confusing the Test Cell with the Control Cell figures, as both are placed closely in the table.', "This number is the total respondents for 'Base - Recall Offer' rather than the total respondents in the Test Cell for the 'Base' section.", "Students might mistakenly take the total respondents for 'Base - Recall Offer' from the Control Cell and apply it to the Test Cell as the total respondents.", "This percentage represents the 'Ever Tried' category in the Test Cell, not the total respondents.", "This percentage is the 'Used Offer' percentage from the Test Cell but can be mistaken if one is correlating base numbers incorrectly.", "This percentage belongs to 'Recall Receiving Offer' and may be mistaken for total respondents if students mix up column headers and row labels."]
# reasoning
# Choices: ['299', '241', '167', '94', '81', '50']
# Reasons: ['This option incorrectly assumes the Control Cell number applies to the Test Cell, suggesting a reversed understanding of the table layout.', "This number is mistakenly taken from the 'Base - Recall Offer' category, not considering that it applies only to specific respondents.", "This is another misreading from the 'Base - Recall Offer' row, implying a misunderstanding of the distinction between total and recall-specific respondents.", "This percentage figure from 'Ever Tried' is confused with a total count, ignoring that it represents a proportion rather than a total respondent number.", "A percentage from 'Recall Receiving Offer' is misinterpreted as total respondents, neglecting that percentages can't represent total counts.", "This option mistakenly uses a percentage from the 'Used Offer' row, failing to differentiate between percentage points and total numbers of respondents."]
# visual_interpretation
# Choices: ['299', '241', '94', '167', '38', '81']
# Reasons: ["This option confuses the 'Control Cell' with the 'Test Cell', which can be visually mistaken due to the similar formatting and proximity of the numbers.", "This misreads the 'Base - Recall Offer' number for the 'Test Cell' instead of focusing on the 'Total Respondents'.", "This is the percentage of respondents that 'Ever Tried' in the 'Control Cell', not the total number of respondents in the 'Test Cell'.", "This option misinterprets the 'Base - Recall Offer' figure in the 'Test Cell', erroneously assuming it represents 'Total Respondents'.", 'This number relates to the percentage usage of the offer and is incorrectly considered as the total respondents by ignoring context.', "This misreads the percentage of people who 'Recall Receiving Offer' in the 'Control Cell', missing the separation from respondent totals."]
# data_processing
# Choices: ['299', '241', '167', '50', '80', '94']
# Reasons: ["This is the number of 'total respondents' in the Control cell, not the Test cell, hence a mix-up between columns.", "This figure represents the 'Base - Recall Offer' in the Control cell, and not 'total respondents,' leading to confusion between different metrics.", "This is the 'Base - Recall Offer' number for the Test Cell, mistakenly taken as the total respondents.", "This percentage refers to 'Used Offer' in the Test cell, possibly confusing percentages with total counts.", "This percentage is related to 'Ever Purchased' in the Test cell and can be confusing when misreading percentages as counts.", "This percentage refers to 'Ever Tried' in the Control cell, mistakenly perceived as part of the total count due to its prominence."]
# question_bias
# Choices: ['299', '167', '241', '50', '97', '61']
# Reasons: ["The figure 299 comes from the 'Control Cell' and is a common mistake due to its proximity and identical labeling format.", "This number represents the 'Base - Recall Offer' for the Test Cell, which might be confused with total respondents because of its similar presentation style.", "241 is the 'Base - Recall Offer' for the 'Control Cell' and might be mistakenly selected due to its visual prominence on the page.", "This value is related to the 'Used Offer' percentage in the 'Test Cell,' and might be incorrectly considered a respondent count due to misinterpretation of percentage values as totals.", "Being the percentage value for 'Ever Tried' in the Test Cell, this number can be mistakenly interpreted as a total if one assumes percentages indicate segment sizes or total counts.", "This represents the 'Recall Receiving Offer' percentage in the Test Cell, which could be misinterpreted as the number of respondents due to its heightened number relative to other percentages."]
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: In $\odot S$, $m \widehat {PQR}=98$, Find $m \widehat {PQ}$.
# Answer: 49
# concept
# Choices: ['98', '49', '24.5', '196', '144', '52']
# Reasons: ["This option confuses the arc measure with the angle measure, not accounting for the inscribed angle theorem which states the angle is half the arc's measure.", 'While this is the correct answer, including it as a distractor can mislead students into thinking it is a repeated incorrect option.', 'This mistakenly assumes that the relationship involves halving both the given measure and the intended calculation step, rather than understanding the angle-arc relationship.', 'This option erroneously doubles the given angle measure instead of halving it, misunderstanding the inscribed angle theorem in circles.', 'This assumes a supplementary angle relationship instead of recognizing that the angle at the center doubles the measure of the inscribed angle.', 'This choice incorrectly assumes a minor adjustment error around rounding or simple arithmetic without understanding the conceptual framework of inscribed angles.']
# reasoning
# Choices: ['98', '196', '82', '65', '25', '124']
# Reasons: ['This option mistakenly assumes the measure of the arc is equal to the measure of the angle subtended by it, without dividing by 2.', 'This option incorrectly doubles the angle measure instead of halving it, misunderstanding the relationship between angle and arc measure.', 'This involves a miscalculation assuming that the central angle used somehow incorrectly accounts for measurements around the circle.', 'This option represents a faulty reasoning where one might average some unrelated angles, not grasping the semicircle interval.', 'This number is derived from subtracting some misunderstood values without accurately applying circle theorem principles.', 'This error arises from mistakenly adding an external element of the diagram, misunderstanding where the value corresponds.']
# visual_interpretation
# Choices: ['196', '98', '49π', '24.5', '51', '92']
# Reasons: ['This option doubles the measure of the angle PQR instead of halving it, misunderstanding that the arc measure should be half of the central angle.', 'The distractor repeats the measure of the angle PQR, mistakenly assuming arc PQ is equal to angle PQR, when it should actually be halved.', 'This distractor wrongly introduces the concept of radians or arc length by attaching a π to the correct numeric answer, which is not necessary here.', 'This option incorrectly suggests taking half of 49, possibly as a result of confusion with dividing steps.', 'This option roundly miscalculates beyond the correct value by mistakenly adding 2 to the actual half of 98.', 'This distractor overlooks the need to divide the original angle of 98 by 2, instead subtracting 6, influenced incorrectly by the radius length visible in the diagram.']
# data_processing
# Choices: ['98', '36', '24.5', '74', '196', '44']
# Reasons: ["This option confuses the value of the inscribed angle (98 degrees) with the arc, missing the fact that the arc's measure is half of this value.", 'This choice results from incorrectly subtracting 62 degrees from 98 instead of dividing 98 by 2.', 'This option mistakenly divides the angle measure by 4 instead of 2, leading to an incorrect value.', 'This value is found by erroneously adding 24 to the correct arc measure of 49, misapplying the bisected angle concept.', 'This choice erroneously doubles the measure of angle PQR instead of dividing it by 2, misunderstanding the relationship between the inscribed angle and the arc.', 'This option results from rounding down an approximate calculation or a misinterpretation of the calculation, leading to a slightly incorrect value.']
# question_bias
# Choices: ['99', '196', '52', '98', '48', '147']
# Reasons: ['This distractor assumes a miscalculation in halving the angle, potentially considering a misplacement of decimal value or arithmetic error.', 'This distractor results from improperly doubling the angle measure instead of correctly halving it, leading to confusion with similar computations.', 'This distractor appears from mistakenly adjusting the angle to an adjacent angle by a minor arithmetic adjustment, like adding 3 instead of calculating half.', 'This option mistakenly repeats the same value of the given angle, suggesting no midpoint computation was recognized, leading to identifying segment PQ as same as angle PQR.', 'This distractor reflects a common miscalculation by failing to adjust halfway correctly, confusing nearest even numbers in the splitting process.', 'This distractor stems from a confusion with unrelated circle properties, such as attempting to interpret 1.5 times the given arc without sufficient context.']
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: How much money does Hector need to buy a European vacation package and an Australian vacation package? (Unit: $)
# Answer: 9606
# concept
# Choices: ['9244', '5634', '12858', '8508', '14664', '6794']
# Reasons: ['This distractor arises from a miscalculation by accidentally adding the African safari package instead of the Australian package.', 'Created by adding the Jamaican and Australian packages, assuming a possible mix-up of destinations.', 'Generated by mistakenly summing the European, African safari, and Caribbean packages, overestimating the total.', 'This option results from subtracting the Caribbean package from the European package total instead of adding the Australian package.', 'Created by mistakenly adding all vacation packages listed, rather than the specific ones asked.', 'Arises from a failure to account for the full amount of the European package, using the cheaper options of Caribbean and Australian packages instead.']
# reasoning
# Choices: ['11658', '13722', '12126', '9722', '10356', '15058']
# Reasons: ['This distractor adds the costs of the European, Australian, and Jamaican vacation packages, mistakenly including Jamaican cost.', 'This option incorrectly sums the European, Australian, and African safari packages, mistakenly including the African safari cost.', 'This distractor erroneously involves the costs of all vacation packages except the Caribbean, leading to a convoluted calculation mistake.', 'This choice incorrectly rounds up the European and Australian package costs, creating a rounding error.', 'This distractor miscalculates by adding an extra $750 to the total, erroneously suggesting extra fees.', 'This option mistakenly includes the total sum of all listed vacation packages, ignoring the specific packages in the question.']
# visual_interpretation
# Choices: ['9,222', '9,606', '11,728', '7,670', '8,034', '5,088']
# Reasons: ['This option may confuse students who misread the African safari vacation package price, thinking it applies to both packages or one of them.', "This option involves a simple transcription error with a transposed '6' and '0', which can easily occur if a student misreads or misremembers the correct total.", 'This option adds all vacation packages instead of just the European and Australian, capturing a student who calculates incorrectly by summing everything.', 'This selects only the price for the European package, which can confuse students if they forget to add the Australian package price.', 'This distractor may result from a partial sum involving the European and one of the other vacation packages due to confusion between items.', 'This represents the Caribbean package price, which can mislead a student who mistakes it for one of the desired packages based on list position.']
# data_processing
# Choices: ['9686', '7434', '15620', '11506', '9544', '5768']
# Reasons: ['The distraction comes from incorrectly adding an extra $80, possibly swapping the digits of the European package’s hundreds and tens place.', 'This distractor results from subtracting the Australian package amount from the European package cost instead of adding.', 'Here, a distractor doubles the European vacation package amount before adding, testing multiplication confusion.', 'This distractor erroneously adds an extra $1,900, mistaking the African safari package cost for the Australian.', 'A simple rounding error by subtracting $32 from the correct total, challenging attention to exact figures.', 'A complete error occurs if someone mistakenly uses the Jamaican vacation package cost instead of European for the sum calculation.']
# question_bias
# Choices: ['9,016', '8,948', '9,092', '10,506', '8,706', '7,982']
# Reasons: ['This distractor arises from misplacing the digits in the sum of the European ($7,670) and Australian ($1,936) packages.', 'This option derives from subtracting a convenient round number like 400 from the correct total, suggesting a simple estimation error.', 'By changing the last digit from 6 to 2, this distractor invites errors from hasty calculations where small mistakes accumulate.', 'This distractor incorrectly adds the amount of the Jamaican package ($5,644) instead of Australian, leveraging a mix-up in reading.', 'Here, the distractor is created by markedly undervaluing the European vacation, substituting a lower figure such as $6,770 for $7,670.', 'This option comes from erroneously adding one other cheaper package, like Caribbean ($5,088), assuming a discounted choice.']
# <PIL.Image.Image image mode=RGB size=384x384>
# Question: Who is the author of this book?
# Answer: Anne Hillerman
# concept
# Choices: ['Tony Hillerman', 'Christina Delaine', 'Douglas Preston', 'Leaphorn & Chee', 'Spider Woman', 'New York Times']
# Reasons: ['Although Tony Hillerman is a well-known author, this book is written by his daughter, Anne Hillerman. The error exploits the family relationship between them.', 'Christina Delaine is mentioned on the cover as the performer, leading to confusion between the performer and the author.', 'Douglas Preston is quoted on the cover, but might be mistaken for the author due to the prominent placement of the quote.', 'These names appear on the cover as characters in the novel series, potentially misleading readers to think they are the authors.', "Spider Woman is part of the book's title, not an author's name, leading to confusion for those unfamiliar with the content.", "The phrase 'New York Times Bestseller' could mislead some into thinking it's related to authorship, despite being unrelated."]
# reasoning
# Choices: ['Tony Hillerman', 'Christina Delaine', 'Douglas Preston', 'Leaphorn & Chee', 'Simon & Schuster', 'Spider Woman']
# Reasons: ['This option is plausible because Tony Hillerman is a well-known author associated with similar genres and themes, leading to a hasty generalization that he authored this book as well.', 'Christina Delaine is mentioned on the cover as the performer, not the author, creating a context neglect error by confusing roles associated with the book.', "Douglas Preston's name appears as a quote attribution, which might mislead someone into thinking he is the author, neglecting the context of his role as a reviewer.", "This option plays on false analogy, mistaking the title's characters for the author due to their prominent mention on the cover.", 'This is a causal inversion, confusing the publishing entity with the author, as Simon & Schuster is the publishing company, not the creator of the content.', "This distractor results from a false analogy, incorrectly assuming 'Spider Woman' to be the author based on the book's title focusing on this character."]
# visual_interpretation
# Choices: ['Spider Woman', 'Tony Hillerman', 'Leaphorn Chee', 'Christina Delaine', 'Douglas Preston', 'Navajo Mystery']
# Reasons: ["This option confuses the title with the author's name, which is a common error when the title is prominently displayed.", "This distractor is plausible because Tony Hillerman is connected to the book series, and a reader might assume he is the author if they are not aware of Anne Hillerman's continuation of the series.", "This option mistakes the characters' names, featured as part of the series description, for the author's name.", "Since Christina Delaine is mentioned on the cover as the performer, a misinterpretation might occur with readers assuming she is involved in the book's creation as the author.", 'Douglas Preston is named on the cover for providing a quote, which could mislead someone into thinking he authored the book.', "This option mistakes a theme from the series for the author's name, as the book might be associated with Navajo culture."]
# data_processing
# Choices: ['Anthony Hillerman', 'Christina Delaine', 'Douglas Preston', 'Tony Chee', 'Leaphorn', 'Chee Leaphorn']
# Reasons: ["This distractor plays on the similarity of the last name and confuses the author's father with the author.", 'This distractor uses the name of the performer of the audiobook, which is mistakenly interpreted as the author.', 'This distractor confuses the name of the person who wrote a quote or review on the cover with the author.', "This distractor uses a character's name from the book's title, misleading those unfamiliar with the book's content.", "This distractor uses another character's name, causing confusion with the book's subtitle.", "This distractor combines two character names from the book's subtitle, creating a plausible but incorrect author name."]
# question_bias
# Choices: ['Tony Hillerman', 'Tony Scott', 'Agatha Christie', 'Arthur Conan Doyle', 'Louise Erdrich', 'Sue Grafton']
# Reasons: ["Tony Hillerman is Anne Hillerman's father and the original creator of the Leaphorn & Chee series, leading to confusion.", 'Tony Scott is a well-known director, and his inclusion here could mislead those unfamiliar with his work in film rather than literature.', 'Agatha Christie, as a famous mystery author, provides a plausible but incorrect choice due to her similar genre focus.', 'Arthur Conan Doyle is a renowned mystery author whose association with detective stories can cause confusion.', 'Louise Erdrich is a prominent author known for works featuring Native American themes, resembling Hillerman’s thematic focus.', 'Sue Grafton is known for her mystery writing, making her seem like a probable author for a detective novel.']
