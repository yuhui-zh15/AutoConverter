# %%
import pandas as pd

# data = pd.read_csv("./yuchang_data/MMMU-1023-MC-2238.tsv", sep="\t")
data = pd.read_csv("./yuchang_data/SEEDBench-1000-MC-4.tsv", sep="\t")

# %%
import pandas as pd
import numpy as np
import os

model = "cambrian_8b"
for filename in os.listdir(f"./yuchang_records_new/{model}"):
    if "SEEDBench" not in filename:
        continue
    data = pd.read_excel(f"./yuchang_records_new/{model}/{filename}").to_dict("records")
    accs = []
    for item in data:
        answer = item["answer"]
        # pred = item["prediction"][0]
        # accs.append(answer == pred)
        pred = item["prediction"]
        accs.append(f" {answer}" in pred)

    acc = np.mean(accs)
    print(f"{filename}: {acc}")
# Out:
# SEEDBench-1000-MC_mc.xlsx: 0.485
# SEEDBench-1000-MC-4_mc.xlsx: 0.546
# SEEDBench-1000-MC-OLD_mc.xlsx: 0.479

# %%
import pandas as pd
import base64
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt

model = "cambrian_8b"
# data = pd.read_csv("./yuchang_data/MMMU-1023-MC-2238.tsv", sep="\t").to_dict("records")
# data1 = pd.read_excel(f"./yuchang_records_new/{model}/MMMU-1023_mc.xlsx").to_dict("records")
# data2 = pd.read_excel(f"./yuchang_records_new/{model}/MMMU-1023-MC-1403_mc.xlsx").to_dict("records")
data = pd.read_csv("./yuchang_data/SEEDBench-1000-MC-4.tsv", sep="\t").to_dict("records")
data1 = pd.read_excel(f"./yuchang_records_new/{model}/SEEDBench-1000-MC_mc.xlsx").to_dict("records")
data2 = pd.read_excel(f"./yuchang_records_new/{model}/SEEDBench-1000-MC-OLD_mc.xlsx").to_dict("records")
print(len(data), len(data1), len(data2))

def is_correct(answer, prediction):
    # return answer == prediction
    return f" {answer}" in prediction

corrects1 = [is_correct(item["answer"], item["prediction"]) for item in data1]
corrects2 = [is_correct(item["answer"], item["prediction"]) for item in data2]


# for i in range(10):
#     item = data[i]
#     image_base64 = item["image"]
#     distractors = [item["A"], item["B"], item["C"], item["D"]]
#     correct_choice = item["answer"]
#     judgment = judge_multichoice_correctness_with_image(image_base64, distractors, correct_choice)
#     print(judgment)


for idx in range(len(data1)):
    if not corrects2[idx] and corrects1[idx]:
        item1 = data1[idx]
        item2 = data2[idx]
        item = data[idx]
        image_base64 = item["image"]
        image_data = base64.b64decode(image_base64)
        image = Image.open(BytesIO(image_data)).resize((256, 256))

        # if "What kind of sugar is this, aldose or ketose?" not in item["question"]: continue

        assert item1["question"] == item2["question"] == item["question"]
        display(image)
        print(item1["question"])
        print([item1["A"], item1["B"], item1["C"], item1["D"]], item1["answer"], item1["prediction"])
        print([item2["A"], item2["B"], item2["C"], item2["D"]], item2["answer"], item2["prediction"])
        # print(data2[idx])
        # print(data1[idx])

        item = item1
        question = item["question"]
        choices = [item["A"], item["B"], item["C"], item["D"]] # [:item['choice_length']]
        correct_choice = item[item["answer"]]
        print(question, choices, correct_choice)
        judgment = judge_multichoice_correctness_with_image(image_base64, question, choices, correct_choice)
        print(judgment)

        item = item2
        question = item["question"]
        choices = [item["A"], item["B"], item["C"], item["D"]]
        correct_choice = item[item["answer"]]
        print(question, choices, correct_choice)
        judgment = judge_multichoice_correctness_with_image(image_base64, question, choices, correct_choice)
        print(judgment)
# Out:
# 1000 1000 1000
# <PIL.Image.Image image mode=RGB size=256x256>
# What is the position of the main object in the image?
# ['Lower center', 'Upper center', 'Center', 'Off-center'] C The main object in the image is the tote bag, which is positioned in the center of the frame. Therefore, the correct answer to the question is:
#
# C. Center
# ['Top left corner', 'Bottom right corner', 'Top right corner', 'Center'] D The main object in the image is the tote bag, which is centrally positioned. Therefore, the correct answer to the question is:
#
# D. Center
# What is the position of the main object in the image? ['Lower center', 'Upper center', 'Center', 'Off-center'] Center
# correct=False explanation="The correct answer 'Center' is not mutually exclusive with 'Lower center' and 'Upper center', as these could be considered specific parts of the 'Center'."
# What is the position of the main object in the image? ['Top left corner', 'Bottom right corner', 'Top right corner', 'Center'] Center
# correct=True explanation="The correct answer 'Center' is mutually exclusive with all other choices ('Top left corner', 'Bottom right corner', 'Top right corner') because the center of an area cannot simultaneously be any of the corners."
# <PIL.Image.Image image mode=RGB size=256x256>
# What is the material of the platform on which the man and the horse are standing?
# ['Sandstone', 'Concrete', 'Stone', 'Granite'] C The material of the platform on which the man and the horse are standing appears to be stone. This is indicated by the visible grain and texture, as well as the way the light reflects off the surface, which is characteristic of stone materials. The options provided are all types of stone, but without specific information on the composition or origin of the sculpture, it is not possible to determine the exact type of stone. However, based on the visual cues, the most accurate answer from the given options would be C. Stone.
# ['Stone', 'Wood', 'Concrete', 'Marble'] A The material of the platform on which the man and the horse are standing appears to be stone. This is indicated by the visible grain and texture, as well as the way the light reflects off the surface, which is characteristic of stone materials. Stone has been a common medium for sculpting such figures, especially in classical and ancient art, due to its durability and the fine detail it can capture. Therefore, the correct answer from the options provided is:
#
# A. Stone
# What is the material of the platform on which the man and the horse are standing? ['Sandstone', 'Concrete', 'Stone', 'Granite'] Stone
# correct=False explanation="'Stone' is not mutually exclusive with 'Sandstone' and 'Granite', as both are types of stone."
# What is the material of the platform on which the man and the horse are standing? ['Stone', 'Wood', 'Concrete', 'Marble'] Stone
# correct=False explanation="The correct answer 'Stone' is not mutually exclusive with 'Marble', as marble is a type of stone."
# <PIL.Image.Image image mode=RGB size=256x256>
# What type of room is pictured in the image?
# ['A home office', 'A sunroom', 'A living room', 'A dining room'] C The room pictured in the image is a living room. This determination is based on several key elements present in the image: the arrangement of the furniture, which is oriented towards socializing and relaxation; the presence of a sofa and armchair, which are typical for a living room setting; and the decorative elements such as artwork and plants, which are commonly used to create a comfortable and inviting atmosphere in a living space. The room does not contain the functional furniture or layout of a dining room, the work-related items of a home office, nor the specific features of a sunroom, such as a sunken floor or large windows designed to capture sunlight. Therefore, the correct answer is C. A living room.
# ['A kitchen', 'A bedroom', 'A bathroom', 'A living room'] D The room pictured in the image is a living room. This determination is based on several key elements present in the image: the presence of a sofa and armchair arranged for socializing or relaxation, the coffee table which is a common piece of furniture in living rooms, and the decorative elements such as artwork and plants that are typically used to create a comfortable and aesthetically pleasing living space. The layout and furnishings do not match the typical features of a kitchen, bedroom, or bathroom, which would have distinct functional areas and items not present in this image. Therefore, the correct answer is:
#
# D. A living room
# What type of room is pictured in the image? ['A home office', 'A sunroom', 'A living room', 'A dining room'] A living room
# correct=False explanation='A living room and a sunroom can overlap, as a sunroom can be used as a living room space.'
# What type of room is pictured in the image? ['A kitchen', 'A bedroom', 'A bathroom', 'A living room'] A living room
# correct=True explanation="Yes, the correct answer 'A living room' is mutually exclusive with all other choices, as a living room cannot simultaneously be a kitchen, bedroom, or bathroom."
# <PIL.Image.Image image mode=RGB size=256x256>
# What color is the sign in the background?
# ['Blue', 'Black', 'Red', 'White'] B The question seems to be based on a misunderstanding as there is no sign present in the image provided. The image is a black and white illustration of a character with steampunk elements, and there are no background elements to describe. Therefore, it is not possible to select an answer from the options given (A. Blue, B. Black, C. Red, D. White) as they do not apply to the content of the image.
# ['Black', 'Green', 'Yellow', 'White'] A The question seems to be based on a misunderstanding as there is no sign present in the image provided. The image is a black and white illustration of a character with steampunk elements, and there are no background elements to describe. Therefore, it is not possible to select an answer from the options given as they do not correspond to the content of the image.
# What color is the sign in the background? ['Blue', 'Black', 'Red', 'White'] Black
# correct=True explanation="Yes, the correct answer 'Black' is mutually exclusive with all other choices ('Blue', 'Red', 'White') as each color is distinct and cannot be true at the same time."
# What color is the sign in the background? ['Black', 'Green', 'Yellow', 'White'] Black
# correct=True explanation="Yes, the correct answer 'Black' is mutually exclusive with all other choices ('Green', 'Yellow', 'White') as these are distinct colors and cannot be true simultaneously."
# <PIL.Image.Image image mode=RGB size=256x256>
# What is the man in the red jacket standing next to?
# ['A group of soccer players', 'A group of basketball players', 'A group of gymnasts', 'A group of rugby players'] A The man in the red jacket is standing next to a group of soccer players. This can be determined by the attire of the individuals in the background, which includes soccer jerseys and shorts, and the context of the setting, which is a soccer field. The presence of the "ÉQUIPE DE FRANCE" banner further supports that this is a soccer-related event. Therefore, the correct answer to the question is:
#
# A. A group of soccer players
# ['A soccer goal', 'A group of soccer players', 'A soccer ball', 'A soccer net'] B The man in the red jacket is standing next to a soccer ball. This can be determined by the presence of the ball's distinctive panels and size, which are consistent with standard soccer balls. The ball is placed on the ground, and the man's proximity to it, along with his attire and the context of the setting, suggests that he is likely involved in a coaching or training activity. Therefore, the correct answer to the question is:
#
# C. A soccer ball
# What is the man in the red jacket standing next to? ['A group of soccer players', 'A group of basketball players', 'A group of gymnasts', 'A group of rugby players'] A group of soccer players
# correct=True explanation="Yes, the correct answer 'A group of soccer players' is mutually exclusive with all other choices because a group of soccer players cannot simultaneously be a group of basketball players, gymnasts, or rugby players."
# What is the man in the red jacket standing next to? ['A soccer goal', 'A group of soccer players', 'A soccer ball', 'A soccer net'] A group of soccer players
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 65
#      63 correct_choice = item[item["answer"]]
#      64 print(question, choices, correct_choice)
# ---> 65 judgment = judge_multichoice_correctness_with_image(image_base64, question, choices, correct_choice)
#      66 print(judgment)
#
# Cell In[2], line 57, in judge_multichoice_correctness_with_image(image_base64, question, choices, correct_choice)
#      43 prompt = f"""
#      44     Analyze the following multiple-choice question choices and correct answer:
#      45
#    (...)
#      53     2. A brief explanation (max 2 sentences) justifying your decision. If answering "No", identify which choice(s) could potentially overlap with the correct answer.
#      54 """
#      56 # Assume the API supports image input alongside text (modify based on actual model/API capabilities)
# ---> 57 response = client.beta.chat.completions.parse(
#      58     model="gpt-4o-2024-08-06",  # Adjust this to the appropriate multimodal model ID if needed
#      59     messages=[
#      60         {"role": "system", "content": "You are a helpful assistant."},
#      61         {"role": "user", "content": [
#      62             {
#      63                 "type": "text",
#      64                 "text": dedent(prompt)
#      65             },
#      66             # {
#      67             #     "type": "image_url",
#      68             #     "image_url": {
#      69             #         "url": f"data:image/jpeg;base64,{image_base64}"
#      70             #     }
#      71             # }
#      72         ]}
#      73     ],
#      74     response_format=Judgement,
#      75     temperature=0  # Set to 0 for deterministic responses
#      76 )
#      78 # Extract and return the assistant's response
#      79 answer = response.choices[0].message.parsed
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/openai/resources/beta/chat/completions.py:115, in Completions.parse(self, messages, model, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, seed, service_tier, stop, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     108 _validate_input_tools(tools)
#     110 extra_headers = {
#     111     "X-Stainless-Helper-Method": "beta.chat.completions.parse",
#     112     **(extra_headers or {}),
#     113 }
# --> 115 raw_completion = self._client.chat.completions.create(
#     116     messages=messages,
#     117     model=model,
#     118     response_format=_type_to_response_format(response_format),
#     119     frequency_penalty=frequency_penalty,
#     120     function_call=function_call,
#     121     functions=functions,
#     122     logit_bias=logit_bias,
#     123     logprobs=logprobs,
#     124     max_tokens=max_tokens,
#     125     n=n,
#     126     parallel_tool_calls=parallel_tool_calls,
#     127     presence_penalty=presence_penalty,
#     128     seed=seed,
#     129     service_tier=service_tier,
#     130     stop=stop,
#     131     stream_options=stream_options,
#     132     temperature=temperature,
#     133     tool_choice=tool_choice,
#     134     tools=tools,
#     135     top_logprobs=top_logprobs,
#     136     top_p=top_p,
#     137     user=user,
#     138     extra_headers=extra_headers,
#     139     extra_query=extra_query,
#     140     extra_body=extra_body,
#     141     timeout=timeout,
#     142 )
#     143 return _parse_chat_completion(
#     144     response_format=response_format,
#     145     chat_completion=raw_completion,
#     146     input_tools=tools,
#     147 )
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/openai/resources/chat/completions.py:668, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     633 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     634 def create(
#     635     self,
#    (...)
#     665     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     666 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     667     validate_response_format(response_format)
# --> 668     return self._post(
#     669         "/chat/completions",
#     670         body=maybe_transform(
#     671             {
#     672                 "messages": messages,
#     673                 "model": model,
#     674                 "frequency_penalty": frequency_penalty,
#     675                 "function_call": function_call,
#     676                 "functions": functions,
#     677                 "logit_bias": logit_bias,
#     678                 "logprobs": logprobs,
#     679                 "max_tokens": max_tokens,
#     680                 "n": n,
#     681                 "parallel_tool_calls": parallel_tool_calls,
#     682                 "presence_penalty": presence_penalty,
#     683                 "response_format": response_format,
#     684                 "seed": seed,
#     685                 "service_tier": service_tier,
#     686                 "stop": stop,
#     687                 "stream": stream,
#     688                 "stream_options": stream_options,
#     689                 "temperature": temperature,
#     690                 "tool_choice": tool_choice,
#     691                 "tools": tools,
#     692                 "top_logprobs": top_logprobs,
#     693                 "top_p": top_p,
#     694                 "user": user,
#     695             },
#     696             completion_create_params.CompletionCreateParams,
#     697         ),
#     698         options=make_request_options(
#     699             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     700         ),
#     701         cast_to=ChatCompletion,
#     702         stream=stream or False,
#     703         stream_cls=Stream[ChatCompletionChunk],
#     704     )
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/openai/_base_client.py:1260, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1246 def post(
#    1247     self,
#    1248     path: str,
#    (...)
#    1255     stream_cls: type[_StreamT] | None = None,
#    1256 ) -> ResponseT | _StreamT:
#    1257     opts = FinalRequestOptions.construct(
#    1258         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1259     )
# -> 1260     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/openai/_base_client.py:937, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928 def request(
#     929     self,
#     930     cast_to: Type[ResponseT],
#    (...)
#     935     stream_cls: type[_StreamT] | None = None,
#     936 ) -> ResponseT | _StreamT:
# --> 937     return self._request(
#     938         cast_to=cast_to,
#     939         options=options,
#     940         stream=stream,
#     941         stream_cls=stream_cls,
#     942         remaining_retries=remaining_retries,
#     943     )
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/openai/_base_client.py:973, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     970 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     972 try:
# --> 973     response = self._client.send(
#     974         request,
#     975         stream=stream or self._should_stream_response_body(request=request),
#     976         **kwargs,
#     977     )
#     978 except httpx.TimeoutException as err:
#     979     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/ssl.py:1258, in SSLSocket.recv(self, buflen, flags)
#    1254     if flags != 0:
#    1255         raise ValueError(
#    1256             "non-zero flags not allowed in calls to recv() on %s" %
#    1257             self.__class__)
# -> 1258     return self.read(buflen)
#    1259 else:
#    1260     return super().recv(buflen, flags)
#
# File /pasteur2/u/yuhuiz/miniconda3/envs/vlmeval/lib/python3.10/ssl.py:1131, in SSLSocket.read(self, len, buffer)
#    1129         return self._sslobj.read(len, buffer)
#    1130     else:
# -> 1131         return self._sslobj.read(len)
#    1132 except SSLError as x:
#    1133     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
from openai import OpenAI
import base64
from pydantic import BaseModel
from textwrap import dedent


class Judgement(BaseModel):
    correct: bool
    explanation: str


client = OpenAI(timeout=20)
def judge_multichoice_correctness_with_image(image_base64: str, question: str, choices: list, correct_choice: str) -> str:
    """
    Judge whether the multiple-choice question is correct based on choices and the image (provided as base64).

    Args:
    image_base64 (str): Base64 encoded image string.
    choices (list): A list of distractor answers.
    correct_choice (str): The correct answer choice.

    Returns:
    str: GPT-4's judgment on whether the question is correct.
    """
    
    # # Construct the prompt for GPT-4o
    # prompt = f"""
    # You are tasked with determining whether a multiple-choice question has clearly one correct answer based on the provided image and choices.
    
    # The image has been encoded in base64 format. Below are the choices and the correct answer.
    
    # Question: {question}
    # Correct Answer: {correct_choice}
    # Distractor Choices: {", ".join(choices)}
    
    # Please analyze the image and determine if the question is correct. Correctness is defined as there being one clearly correct answer, with the choices representing different concepts.
    # If you cannot understand the image or answer the question, please provide a judgment based on the choices only to see if choices are different enough.

    # Provide a yes/no answer and explain in at most 2 sentences.
    # """

    # Construct the prompt for GPT-4o
    prompt = f"""
        Analyze the following multiple-choice question choices and correct answer:

        Choices: {choices}
        Correct Answer: {correct_choice}

        Task: Determine if the correct answer is mutually exclusive with all other choices. This means it should be impossible for the correct answer and any other choice to both be true simultaneously.

        Respond with:
        1. "Yes" if the correct answer is mutually exclusive with all other choices, or "No" if there's any possibility of overlap between the correct answer and any other choice.
        2. A brief explanation (max 2 sentences) justifying your decision. If answering "No", identify which choice(s) could potentially overlap with the correct answer.
    """

    # Assume the API supports image input alongside text (modify based on actual model/API capabilities)
    response = client.beta.chat.completions.parse(
        model="gpt-4o-2024-08-06",  # Adjust this to the appropriate multimodal model ID if needed
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": [
                {
                    "type": "text",
                    "text": dedent(prompt)
                },
                # {
                #     "type": "image_url",
                #     "image_url": {
                #         "url": f"data:image/jpeg;base64,{image_base64}"
                #     }
                # }
            ]}
        ],
        response_format=Judgement,
        temperature=0  # Set to 0 for deterministic responses
    )
    
    # Extract and return the assistant's response
    answer = response.choices[0].message.parsed
    return answer
